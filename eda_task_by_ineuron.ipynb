# %%
import pandas_profiling

# %%
from pandas_profiling import ProfileReport

# %%
import os
import pandas as pd

# %%
os.chdir("C:\\Users\\apurv\\OneDrive\\Desktop\\Dataset\\data0")

# %%
pwd()
# Out:
# 'C:\\Users\\apurv\\OneDrive\\Desktop\\Dataset\\data0'

# %%
a=pd.read_csv('aug_test.csv')

# %%
ProfileReport(a)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-11-13 05:20:51.315260&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
import dtale
import pandas as pd
n=pd.read_csv("aug_test.csv")
dtale.show(n)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Rog-Apurva:40000/dtale/iframe/8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
from autoviz.AutoViz_Class import AutoViz_Class
autoviz = AutoViz_Class().AutoViz('aug_test.csv')
# Out:
# Shape of your Data Set loaded: (2129, 13)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# Data cleaning improvement suggestions. Complete them before proceeding to ML modeling.
# <style type="text/css">
# #T_41d02_row0_col0, #T_41d02_row0_col4, #T_41d02_row7_col2, #T_41d02_row7_col3, #T_41d02_row12_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# ...

# %%
pip install dtale==2.9.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -weetviz (c:\users\apurv\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -weetviz (c:\users\apurv\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -weetviz (c:\users\apurv\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -weetviz (c:\users\apurv\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -weetviz (c:\users\apurv\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -weetviz (c:\users\apurv\anaconda3\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install dtale==1.40.2
# Out:
# ...
#      ---------------------------------------- 14.2/14.2 MB 9.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: statsmodels in c:\users\apurv\anaconda3\lib\site-packages (from dtale==1.40.2) (0.13.2)
# ...
# WARNING: Ignoring invalid distribution -weetviz (c:\users\apurv\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -weetviz (c:\users\apurv\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -weetviz (c:\users\apurv\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -weetviz (c:\users\apurv\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -weetviz (c:\users\apurv\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -weetviz (c:\users\apurv\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -weetviz (c:\users\apurv\anaconda3\lib\site-packages)
# ...

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# agate                         1.6.3
# agate-dbf                     0.2.2
# agate-excel                   0.2.5
# agate-sql                     0.5.8
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# async-generator               1.10
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# ...
